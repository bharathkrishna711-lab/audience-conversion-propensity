# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib

from sklearn.model_selection import train_test_split

# %%
df = pd.read_excel(r"C:\Users\bhara\OneDrive\Desktop\INTERVIEW PREPS\ML PROJECT 1\Audience-Conversion-Propensity\notebooks\data\raw\cohort_conversion_dataset.xlsx")
df.columns = df.columns.str.strip()

# %%
best_model = joblib.load("models/logit_pipeline.joblib")
print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
df["clicks_per_user"] = df["clicks_7d"] / (df["users_exposed"] + 1)
df["add_to_cart_rate"] = df["add_to_cart_7d"] / (df["users_exposed"] + 1)
df["frequency_recency_ratio"] = df["avg_frequency_7d"] / (df["recency_hours"] + 1)
df["seasonal_engagement"] = df["add_to_cart_rate"] * df["seasonality_index"]

# %%
threshold = df["conversion_rate_7d"].quantile(0.80)
df["converted_7d"] = (df["conversion_rate_7d"] >= threshold).astype(int)

# %%
FEATURES = [
    "users_exposed","impressions_7d","avg_frequency_7d","recency_hours",
    "clicks_7d","ctr_7d","site_visits_7d","product_views_7d",
    "add_to_cart_7d","avg_session_time_sec",
    "prev_conv_rate_28d","seasonality_index",
    "clicks_per_user","add_to_cart_rate","frequency_recency_ratio","seasonal_engagement",
    "geo","device","audience_segment","product_category"
]

X = df[FEATURES]
y = df["converted_7d"]

# %%
_, X_test, _, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
y_prob = best_model.predict_proba(X_test)[:,1]

# %%
print("Shape:", y_prob.shape)
print("Mean propensity:", y_prob.mean())
print("Min / Max:", y_prob.min(), y_prob.max())
# Out:
# Shape: (1000,)
# Mean propensity: 0.20063986351328458
# Min / Max: 4.66967071412416e-05 0.961679649948535

# %%
from sklearn.metrics import roc_auc_score

roc_auc = roc_auc_score(y_test, y_prob)
print("ROC-AUC:", roc_auc)
# Out:
# ROC-AUC: 0.9325843438746665

# %%
simulation_results = X_test.copy()
simulation_results["actual_converted"] = y_test.values
simulation_results["propensity_score"] = y_prob

simulation_results = simulation_results.sort_values(
    "propensity_score", ascending=False
)

simulation_results.head(10)
# Out:
#       users_exposed  impressions_7d  avg_frequency_7d  recency_hours  \
# 4613          39996          154297               3.6             15
# 4796          17357           26825               1.6             18
# 4626          40192          230999               5.3             93
# 4952          47923          109865               2.5             78
# 4593          17574           32993               1.8             10
# 4298          28199           92172               3.5             14
# 4210          55327          217922               4.2             66
# 4158          11407           59031               5.0             77
# 4077          29779           67354               2.1             10
# 4597          48899          265192               5.3             11
#
#       clicks_7d  ctr_7d  site_visits_7d  product_views_7d  add_to_cart_7d  \
# 4613       4606  0.0299           17943              8925            2829
# 4796        698  0.0260            3468              2002             340
# 4626       3600  0.0156           12285              6212            2073
# 4952       1212  0.0110            4087              1976             350
# 4593        566  0.0172            1987               960             200
# 4298       1206  0.0131            5455              3062             735
# 4210       5078  0.0233           19577             12262            3481
# 4158       1607  0.0272            5411              2253             362
# 4077       1472  0.0219            5455              3232             499
# 4597       5671  0.0214           24633             10145            2858
#
#       avg_session_time_sec  ...  clicks_per_user  add_to_cart_rate  \
# 4613                   146  ...         0.115159          0.070730
# 4796                   195  ...         0.040212          0.019588
# 4626                   132  ...         0.089568          0.051576
# 4952                   125  ...         0.025290          0.007303
# 4593                   166  ...         0.032205          0.011380
# 4298                   171  ...         0.042766          0.026064
# 4210                   221  ...         0.091780          0.062916
# 4158                   203  ...         0.140866          0.031732
# 4077                   281  ...         0.049429          0.016756
# 4597                   132  ...         0.115971          0.058446
#
#       frequency_recency_ratio  seasonal_engagement  geo   device  \
# 4613                 0.225000             0.076389   IN  Desktop
# 4796                 0.084211             0.022134   IN  Desktop
# 4626                 0.056383             0.057250   US   Mobile
# 4952                 0.031646             0.008107   UK  Desktop
# 4593                 0.163636             0.012859   UK   Mobile
# 4298                 0.233333             0.028931   UK   Mobile
# 4210                 0.062687             0.070466   IN   Mobile
# 4158                 0.064103             0.035540   US  Desktop
# 4077                 0.190909             0.017929   UK   Mobile
# 4597                 0.441667             0.065459   US   Mobile
#
#          audience_segment product_category actual_converted propensity_score
# 4613          Book Lovers            Books                1         0.961680
# 4796        Tech Shoppers      Electronics                1         0.952446
# 4626  Fitness Enthusiasts      Fitness App                1         0.950138
# 4952      Casual Browsers            Books                1         0.943357
# 4593          New Parents        Baby Care                1         0.940646
# 4298          New Parents        Baby Care                1         0.938925
# 4210      Luxury Shoppers           Luxury                1         0.937971
# 4158      Casual Browsers            Books                1         0.935016
# 4077          Book Lovers            Books                1         0.934150
# 4597        Beauty Buyers           Beauty                1         0.929410
#
# [10 rows x 22 columns]

# %%
segment_summary = (
    simulation_results
    .groupby("audience_segment")
    .agg(
        avg_propensity=("propensity_score", "mean"),
        conversion_rate=("actual_converted", "mean"),
        count=("propensity_score", "size")
    )
    .sort_values("avg_propensity", ascending=False)
)

segment_summary
# Out:
#                      avg_propensity  conversion_rate  count
# audience_segment
# Tech Shoppers              0.227771         0.196850    127
# Luxury Shoppers            0.221862         0.194444    108
# Fitness Enthusiasts        0.211167         0.204380    137
# New Parents                0.210039         0.208054    149
# Book Lovers                0.198185         0.189655    116
# Beauty Buyers              0.197811         0.194915    118
# Casual Browsers            0.171456         0.158333    120
# Deal Seekers               0.164962         0.136000    125
